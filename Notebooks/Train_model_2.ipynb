# %%
import os


import numpy as np
import torch
from torch import nn
from pytorch_lightning.callbacks import ModelCheckpoint
from src.models.plModel import LightningModel
from src.utils.OneSimDataloader import DataModule
import pytorch_lightning as pl

from pytorch_lightning import Trainer

# %%
import seaborn as sns
import matplotlib 
from matplotlib import pyplot as plt

# %%
GPUS = 1
N_EPOCHS = 100

# %%
data_module = DataModule(batch_size=256,num_workers=40)
data_module.setup()
# Out:
# Calculated tendencies
# Inputs Created
# Created Outputs
# Train Test Val Split Done

# %%
x,updates,rates,y=data_module.train_dataset[:]

# %%
def cli_main():
    pl.seed_everything(42)

   

    data_module = DataModule(batch_size=256,num_workers=40,sim_num=700)
    data_module.setup()

    # setting up the model:
    pl_model = LightningModel(updates_mean=data_module.updates_mean,updates_std=data_module.updates_std)

    if GPUS < 1:
        callbacks = None
    else:
        callbacks = [pl.callbacks.GPUStatsMonitor()]

    # initializes a callback to save the 5 best model weights measured by the lowest generator loss:
    checkpoint_callback = ModelCheckpoint(monitor="val_loss", save_top_k=1, mode='min', save_last=True)

    trainer = pl.Trainer(callbacks=callbacks, checkpoint_callback=checkpoint_callback, gpus=GPUS, max_epochs=N_EPOCHS,distributed_backend="ddp")

    trainer.fit(pl_model,data_module)

    return data_module,pl_model,trainer


if __name__ == '__main__':
     _dm,_model, _trainer = cli_main()
# Out:
# Global seed set to 42
# Calculated tendencies
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# Using environment variable NODE_RANK for node rank (0).
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Global seed set to 42
#
#   | Name  | Type      | Params
# ------------------------------------
# 0 | model | plNetwork | 163 K
# ------------------------------------
# 163 K     Trainable params
# 0         Non-trainable params
# 163 K     Total params
# Inputs Created
# Created Outputs
# Train Test Val Split Done
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# ...

# %%
pl_model = LightningModel(updates_mean=data_module.updates_mean,updates_std=data_module.updates_std)
new_model = pl_model.load_from_checkpoint("/gpfs/work/sharmas/mc-snow-data/lightning_logs/version_568293/checkpoints/epoch=91-step=54003.ckpt")

# %%
class simulation_forecast:
    def __init__(self, arr,new_model,sim_number,data_module):
        self.arr=arr
        self.sim_number=sim_number
        self.data_module=data_module
        self.model=new_model
        self.moment_preds=[]
        
    def setup(self):
        
        
        arr=self.arr.astype(np.float32)
        #self.arr=np.mean(arr[:,:,719:-1,:],axis=-1)
        arr_new=np.delete((arr[:,:,:]),[3,6],1)
        k=np.ma.getmask(self.arr)
        k_new=np.delete((k[:,:,:]),[3,6],1)
        self.test_sims = np.ma.masked_where(k_new, arr_new)
        print(self.test_sims.shape)
        
    def test(self):
        self.setup()
        self.orig=np.ma.compress_rows(self.test_sims[:,1:5,self.sim_number])
        self.sim_data=self.test_sims[0,1:,self.sim_number]
        self.model_params=self.sim_data[-4:-1]
        self.create_input()
        predictions_updates=self.model.forward(torch.from_numpy(self.inputs))
        self.moment_calc(predictions_updates)
        
        for i in range (1,np.ma.compress_rows(self.test_sims[:,:,self.sim_number]).shape[0]):
            
            
            self.create_input()
            predictions_updates=self.model.forward(torch.from_numpy(self.inputs))
            self.moment_calc(predictions_updates)
            
        
    def calc_mean(self,no_norm,means,stds):
         return (no_norm-means.reshape(-1,))/stds.reshape(-1,)
        
        
    def create_input(self):
        tau=self.sim_data[2]/(self.sim_data[2]+self.sim_data[0])
        xc=self.sim_data[0]/self.sim_data[1]
        inputs=np.concatenate((self.sim_data[0:4].reshape(1,-1),tau.reshape(1,-1),xc.reshape(1,-1),self.model_params.reshape(1,-1)),axis=1)
        #new_input_=np.concatenate((predictions_orig_[:,0:],self.model_params.reshape(1,-1),tau.reshape(1,-1),xc.reshape(1,-1)),axis=1)
        
        self.inputs=self.calc_mean(inputs,self.data_module.inputs_mean,self.data_module.inputs_std)
        self.inputs=np.float32(self.inputs)
       
        
    def moment_calc(self,predictions_updates):
        self.updates=(predictions_updates.detach().numpy()*self.data_module.updates_std)+self.data_module.updates_mean
        #=self.calc_mean(predictions_updates.detach().numpy(),self.data_module.updates_mean,self.data_module.updates_std)
        #x_orig=(x[:4]*(data_module.outputs_std))+data_module.outputs_mean
        self.preds=self.sim_data[0:4]+(self.updates*20)
        self.moment_preds.append(self.preds)
        self.sim_data=self.preds.reshape(-1,)

# %%
from matplotlib.pyplot import cm
from matplotlib import ticker
def plot_simulation(predictions_orig,targets_orig,sb_preds,model_params,var_all,num):
    sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
    var=['Lc','Nc','Lr','Nr']
    color=["#26235b","#bc473a","#812878","#f69824"]
    fig= plt.figure()
    fig.set_size_inches(13, 10)
    time= [x for x in range(0, len(predictions_orig))]
    #color=iter(cm.rainbow(np.linspace(0,1,4)))
    for i in range(4):
        ax = fig.add_subplot(2,2, i + 1)
        #c=next(color)
        plt.plot(time[:],predictions_orig[:,i],c=color[i])
        plt.plot(time[:],targets_orig[:,i],c='black')
        plt.plot(time[:-1],sb_preds[:,i],c=color[i],linestyle='dashed')
        plt.fill_between(time[:], targets_orig[:,i]-var_all[:len(time),i], targets_orig[:,i]+var_all[:len(time),i],facecolor = "gray")
        #plt.plot(time[:], targets_orig[:,i]-var_all[:len(time),i])
        plt.title(var[i])
        plt.xlabel('Timestep')    

        plt.legend(['Neural Network','Simulations','SB2001'])

   
    
    #fig.suptitle("Lo:{(model_params)[:,0]}; rm:{(model_params)[:,1]}; Nu:{model_params[:,2]}", fontsize="x-large")
    
    
    fig.suptitle("Lo: %.4f; rm:%.6f ; Nu: %.1f Trained on %.0f sims "%((model_params)[:,0],(model_params)[:,1],(model_params)[:,2],num), fontsize="x-large")
    plt.show()

# %%
class SB_forecast:
    
    kcc = 9.44e9      # Long kernel in m3 kg-2 s-1 
    kcr = 5.78        # Long kernel in m3 kg-1 s-1 
    krr = 4.33

    xstar = 2.6e-10   # xstar in kg
    a_phi = 600.
    p_phi = 0.68
    rhow = 1e3
    
    def __init__(self,arr, sim_num):
        
        
        #self.model_params=d[self.start_point,5:8].to('cpu').numpy()*sds[4:7].reshape(1, -1) + means[4:7].reshape(1, -1)
        
        self.lo=arr[0,-4,sim_num]
        self.rm=arr[0,-3,sim_num]
        self.nu=arr[0,-1,sim_num]
        
        
        self.lc=arr[0,1,sim_num]
        self.nc=arr[0,2,sim_num]
        self.lr=arr[0,4,sim_num]
        self.nr=arr[0,5,sim_num]
        
        self.auto=None
        self.acc=None
        self.scc=None
        self.scr=None
        self.xc0=None
        

        self.predictions=[]
        self.test_sims=arr
        self.sim_num=sim_num
    
    
    def SB_calc(self):
        for i in range (1,np.ma.compress_rows(self.test_sims[:,:,self.sim_num]).shape[0]):
            self.autoconSB()
            self.accretionSB()
            self.selfcloudSB()
            self.selfrainSB()
            self.solve_ode()
            self.predictions.append([self.lc,self.nc,self.lr,self.nr])

        
    @staticmethod
    def drop_mass(r):
      
        return 4./3. *np.pi * SB_forecast.rhow * (r)**3

    def autoconSB(self):
    
        nu=self.nu
        xc=self.lc/self.nc
        auto = SB_forecast.kcc/(20*SB_forecast.xstar) * (nu+2.0)*(nu+4.0)/(nu+1.0)**2 * self.lc**2 * xc**2
        tau  = self.lr/(self.lc+self.lr+1e-15)
        taup = np.power(tau,SB_forecast.p_phi)
        phi  = SB_forecast.a_phi * taup * (1.0 - taup)**3
        self.auto = auto * (1.0+phi)


    def accretionSB(self):
  
        tau = self.lr/(self.lc+self.lr)
        phi = (tau / (tau + 5e-4))**4
        self.acc = SB_forecast.kcr * self.lc * self.lr * phi
        

    def selfcloudSB(self):
     
        self.scc= SB_forecast.kcc * (self.nu+2.0)/(self.nu+1.0) * self.lc**2
     

    def selfrainSB(self):
 
        self.scr = SB_forecast.krr * self.lr * self.nr
      

    def solve_ode(self):
        dt=5
        xm=SB_forecast.drop_mass(self.rm)
        autoN = 1.0/SB_forecast.xstar*self.auto
        accrN = self.acc/xm
        for i in range (4):
            self.lc = self.lc - self.auto*dt - self.acc*dt
            self.lr = self.lr + self.auto*dt + self.acc*dt
            self.nc = self.nc - accrN*dt - self.scc*dt
            self.nr = self.nr + autoN*dt - self.scr*dt

# %%
with np.load('/gpfs/work/sharmas/mc-snow-data/same_sim.npz') as npz:
        all_arr = np.ma.MaskedArray(**npz)
        
all_arr=all_arr.astype(np.float32)

# %%
all_arr.shape
# Out:
# (194, 18, 1, 960)

# %%
def calc_errors(all_arr,n):

    var_1=np.std(all_arr[:,1,n,:],axis=-1)
    var_2=np.std(all_arr[:,2,n,:],axis=-1)
    var_3=np.std(all_arr[:,4,n,:],axis=-1)
    var_4=np.std(all_arr[:,5,n,:],axis=-1)
    var_all=np.concatenate((var_1.reshape(1,-1),var_2.reshape(1,-1),var_3.reshape(1,-1),var_4.reshape(1,-1)),axis=0)
    return var_all

# %%
arr.shape
# Out:
# (194, 18, 1)

# %%
arr=np.mean(all_arr,axis=-1)

# %%
#arr=data_module.holdout_arr
#arr=data_module.arr.squeeze()
#arr=all_arr[:,:,:,9]
#import timeit

#start = timeit.default_timer()

pl_model = LightningModel(updates_mean=data_module.updates_mean,updates_std=data_module.updates_std)
new_model = pl_model.load_from_checkpoint("/gpfs/work/sharmas/mc-snow-data/lightning_logs/version_570508/checkpoints/last.ckpt")
sim_num=0
new_forecast=simulation_forecast(arr,new_model,sim_num, data_module)
new_forecast.test()
#stop = timeit.default_timer()

#print('Time: ', stop - start) 

sb_forecast=SB_forecast(arr,sim_num)
sb_forecast.SB_calc()
predictions_sb=np.asarray(sb_forecast.predictions).reshape(-1,4)
var_all=np.transpose(calc_errors(all_arr,sim_num))
plot_simulation(np.asarray(new_forecast.moment_preds).reshape(-1,4),new_forecast.orig,predictions_sb,new_forecast.model_params.reshape(1,-1),var_all,num=100)
# Out:
# (194, 16, 1)

# %%
#arr=data_module.holdout_arr
#arr=data_module.arr.squeeze()
#arr=all_arr[:,:,:,9]
#import timeit

#start = timeit.default_timer()

pl_model = LightningModel(updates_mean=data_module.updates_mean,updates_std=data_module.updates_std)
new_model = pl_model.load_from_checkpoint("/gpfs/work/sharmas/mc-snow-data/lightning_logs/version_570509/checkpoints/epoch=85-step=15823.ckpt")
sim_num=0
new_forecast=simulation_forecast(arr,new_model,sim_num, data_module)
new_forecast.test()
#stop = timeit.default_timer()

#print('Time: ', stop - start) 

sb_forecast=SB_forecast(arr,sim_num)
sb_forecast.SB_calc()
predictions_sb=np.asarray(sb_forecast.predictions).reshape(-1,4)
var_all=np.transpose(calc_errors(all_arr,sim_num))
plot_simulation(np.asarray(new_forecast.moment_preds).reshape(-1,4),new_forecast.orig,predictions_sb,new_forecast.model_params.reshape(1,-1),var_all,num=300)
# Out:
# (194, 16, 1)

# %%
#arr=data_module.holdout_arr
#arr=data_module.arr.squeeze()
#arr=all_arr[:,:,:,9]
#import timeit

#start = timeit.default_timer()

pl_model = LightningModel(updates_mean=data_module.updates_mean,updates_std=data_module.updates_std)
new_model = pl_model.load_from_checkpoint("/gpfs/work/sharmas/mc-snow-data/lightning_logs/version_570510/checkpoints/epoch=80-step=24785.ckpt")
sim_num=0
new_forecast=simulation_forecast(arr,new_model,sim_num, data_module)
new_forecast.test()
#stop = timeit.default_timer()

#print('Time: ', stop - start) 

sb_forecast=SB_forecast(arr,sim_num)
sb_forecast.SB_calc()
predictions_sb=np.asarray(sb_forecast.predictions).reshape(-1,4)
var_all=np.transpose(calc_errors(all_arr,sim_num))
plot_simulation(np.asarray(new_forecast.moment_preds).reshape(-1,4),new_forecast.orig,predictions_sb,new_forecast.model_params.reshape(1,-1),var_all,num=500)
# Out:
# (194, 16, 1)

# %%
#arr=data_module.holdout_arr
#arr=data_module.arr.squeeze()
#arr=all_arr[:,:,:,9]
#import timeit

#start = timeit.default_timer()

pl_model = LightningModel(updates_mean=data_module.updates_mean,updates_std=data_module.updates_std)
new_model = pl_model.load_from_checkpoint("/gpfs/work/sharmas/mc-snow-data/lightning_logs/570513/checkpoints/last.ckpt")
sim_num=0
new_forecast=simulation_forecast(arr,new_model,sim_num, data_module)
new_forecast.test()
#stop = timeit.default_timer()

#print('Time: ', stop - start) 

sb_forecast=SB_forecast(arr,sim_num)
sb_forecast.SB_calc()
predictions_sb=np.asarray(sb_forecast.predictions).reshape(-1,4)
var_all=np.transpose(calc_errors(all_arr,sim_num))
plot_simulation(np.asarray(new_forecast.moment_preds).reshape(-1,4),new_forecast.orig,predictions_sb,new_forecast.model_params.reshape(1,-1),var_all,num=700)
# Out:
# (194, 16, 1)

# %%
#arr=data_module.holdout_arr
#arr=data_module.arr.squeeze()
#arr=all_arr[:,:,:,9]
#import timeit

#start = timeit.default_timer()

pl_model = LightningModel(updates_mean=data_module.updates_mean,updates_std=data_module.updates_std)
new_model = pl_model.load_from_checkpoint("/gpfs/work/sharmas/mc-snow-data/lightning_logs/version_570512/checkpoints/epoch=68-step=37949.ckpt")
sim_num=0
new_forecast=simulation_forecast(arr,new_model,sim_num, data_module)
new_forecast.test()
#stop = timeit.default_timer()

#print('Time: ', stop - start) 

sb_forecast=SB_forecast(arr,sim_num)
sb_forecast.SB_calc()
predictions_sb=np.asarray(sb_forecast.predictions).reshape(-1,4)
var_all=np.transpose(calc_errors(all_arr,sim_num))
plot_simulation(np.asarray(new_forecast.moment_preds).reshape(-1,4),new_forecast.orig,predictions_sb,new_forecast.model_params.reshape(1,-1),var_all,num=900)
# Out:
# (194, 16, 1)
